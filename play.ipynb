# %%
pip install pandas numpy matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ------------------------- -------------- 7.1/11.1 MB 35.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 36.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ----------------------------- ---------- 9.4/12.9 MB 45.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 42.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 8.3/8.3 MB 46.3 MB/s  0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 41.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
# ...
